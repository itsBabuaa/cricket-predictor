# %%
import pandas as pd
import numpy as np

# %%
match= pd.read_csv('matches.csv')
deli= pd.read_csv('deliveries.csv')

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
match.shape
# Out:
# (1095, 20)

# %%
deli.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
deli.shape
# Out:
# (260920, 17)

# %%
total_score_df= deli.groupby(['match_id', 'inning']).sum()['total_runs'].reset_index()

# %%
total_score_df= total_score_df[total_score_df['inning']== 1]

# %%
total_score_df['total_runs']= total_score_df['total_runs'] + 1

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         223
# 2       335983       1         241
# 4       335984       1         130
# 6       335985       1         166
# 8       335986       1         111
# ...        ...     ...         ...
# 2207   1426307       1         215
# 2209   1426309       1         160
# 2211   1426310       1         173
# 2213   1426311       1         176
# 2215   1426312       1         114
#
# [1095 rows x 3 columns]

# %% [markdown]
# # merge total_score_df to match.csv on 'id'

# %%
match_df= match.merge(total_score_df[['match_id', 'total_runs']], left_on= 'id', right_on= 'match_id')

# %%
match_df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...   result  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore  ...     runs
# 1          Chennai Super Kings          Chennai Super Kings  ...     runs
# 2             Rajasthan Royals             Rajasthan Royals  ...  wickets
# 3  Royal Challengers Bangalore               Mumbai Indians  ...  wickets
# 4              Deccan Chargers              Deccan Chargers  ...  wickets
#
#   result_margin target_runs  target_overs  super_over  method    umpire1  \
# 0         140.0       223.0          20.0           N     NaN  Asad Rauf
# 1          33.0       241.0          20.0           N     NaN  MR Benson
# 2           9.0       130.0          20.0           N     NaN  Aleem Dar
# 3           5.0       166.0          20.0           N     NaN   SJ Davis
# 4           5.0       111.0          20.0           N     NaN  BF Bowden
#
#           umpire2 match_id total_runs
# 0     RE Koertzen   335982        223
# 1      SL Shastri   335983        241
# 2  GA Pratapkumar   335984        130
# 3       DJ Harper   335985        166
# 4     K Hariharan   335986        111
#
# [5 rows x 22 columns]

# %% [markdown]
# # removing old teams

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams= [
    'Mumbai Indians', 
    'Kolkata Knight Riders',
    'Rajasthan Royals',
    'Chennai Super Kings',
    'Sunrisers Hyderabad',
    'Delhi Capitals',
    'Punjab Kings',
    'Lucknow Super Giants', 
    'Gujarat Titans',
    'Royal Challengers Bengaluru'
]

# %%
match_df['team1']= match_df['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team2']= match_df['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['winner']= match_df['winner'].str.replace('Delhi Daredevils', 'Delhi Capitals')

match_df['team1']= match_df['team1'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
match_df['team2']= match_df['team2'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
match_df['winner']= match_df['winner'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')

match_df['team1']= match_df['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['team2']= match_df['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['winner']= match_df['winner'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

match_df['team1']= match_df['team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['team2']= match_df['team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['winner']= match_df['winner'].str.replace('Kings XI Punjab', 'Punjab Kings')

# %%
match_df= match_df[match_df['team1'].isin(teams)]
match_df= match_df[match_df['team2'].isin(teams)]

# %%
match_df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner  ...   result  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore  ...     runs
# 1          Chennai Super Kings          Chennai Super Kings  ...     runs
# 2             Rajasthan Royals             Rajasthan Royals  ...  wickets
# 3  Royal Challengers Bengaluru               Mumbai Indians  ...  wickets
# 4          Sunrisers Hyderabad              Deccan Chargers  ...  wickets
#
#   result_margin target_runs  target_overs  super_over  method    umpire1  \
# 0         140.0       223.0          20.0           N     NaN  Asad Rauf
# 1          33.0       241.0          20.0           N     NaN  MR Benson
# 2           9.0       130.0          20.0           N     NaN  Aleem Dar
# 3           5.0       166.0          20.0           N     NaN   SJ Davis
# 4           5.0       111.0          20.0           N     NaN  BF Bowden
#
#           umpire2 match_id total_runs
# 0     RE Koertzen   335982        223
# 1      SL Shastri   335983        241
# 2  GA Pratapkumar   335984        130
# 3       DJ Harper   335985        166
# 4     K Hariharan   335986        111
#
# [5 rows x 22 columns]

# %%
match_df.shape
# Out:
# (980, 22)

# %% [markdown]
# # taking only matches with no rain

# %%
match_df['method']= match_df['method'].fillna(0)

# %%
match_df= match_df[match_df['method']== 0]

# %%
match_df= match_df[['match_id', 'city', 'winner', 'total_runs']]

# %%
match_df.head()
# Out:
#    match_id        city                       winner  total_runs
# 0    335982   Bangalore        Kolkata Knight Riders         223
# 1    335983  Chandigarh          Chennai Super Kings         241
# 2    335984       Delhi               Delhi Capitals         130
# 3    335985      Mumbai  Royal Challengers Bengaluru         166
# 4    335986     Kolkata        Kolkata Knight Riders         111

# %%
delivery_df= match_df.merge(deli, on= 'match_id')

# %%
delivery_df= delivery_df[delivery_df['inning']== 2]

# %%
delivery_df['current_score']= delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left']= delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df['balls_left']= 120 - (delivery_df['over']*6  + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders           114       2
# 230978   1426312    Chennai  Kolkata Knight Riders           114       2
# 230979   1426312    Chennai  Kolkata Knight Riders           114       2
# 230980   1426312    Chennai  Kolkata Knight Riders           114       2
# 230981   1426312    Chennai  Kolkata Knight Riders           114       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 230977        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 230978        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 230979        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 230980        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 230981        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... extra_runs total_runs_y  extras_type  is_wicket  \
# 124     R Dravid  ...          0            1          NaN          0
# 125     W Jaffer  ...          1            1        wides          0
# 126     W Jaffer  ...          0            0          NaN          0
# 127     W Jaffer  ...          0            1          NaN          0
# 128     R Dravid  ...          0            1          NaN          0
# ...          ...  ...        ...          ...          ...        ...
# 230977   SS Iyer  ...          0            1          NaN          0
# 230978   VR Iyer  ...          0            1          NaN          0
# 230979   VR Iyer  ...          0            1          NaN          0
# 230980   SS Iyer  ...          0            1          NaN          0
# 230981   VR Iyer  ...          0            1          NaN          0
#
#         player_dismissed dismissal_kind  fielder current_score runs_left  \
# 124                  NaN            NaN      NaN             1       222
# 125                  NaN            NaN      NaN             2       221
# 126                  NaN            NaN      NaN             2       221
# 127                  NaN            NaN      NaN             3       220
# 128                  NaN            NaN      NaN             4       219
# ...                  ...            ...      ...           ...       ...
# 230977               NaN            NaN      NaN           110         4
# 230978               NaN            NaN      NaN           111         3
# 230979               NaN            NaN      NaN           112         2
# 230980               NaN            NaN      NaN           113         1
# 230981               NaN            NaN      NaN           114         0
#
#        balls_left
# 124           119
# 125           118
# 126           117
# 127           116
# 128           115
# ...           ...
# 230977         61
# 230978         60
# 230979         59
# 230980         58
# 230981         57
#
# [111721 rows x 23 columns]

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')

# %%
wickets = delivery_df.groupby('match_id')['player_dismissed'].cumsum()
delivery_df['wickets'] = 10 - wickets
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           223       2
# 125    335982  Bangalore  Kolkata Knight Riders           223       2
# 126    335982  Bangalore  Kolkata Knight Riders           223       2
# 127    335982  Bangalore  Kolkata Knight Riders           223       2
# 128    335982  Bangalore  Kolkata Knight Riders           223       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs_y extras_type  is_wicket  player_dismissed  \
# 124  ...            1         NaN          0                 0
# 125  ...            1       wides          0                 0
# 126  ...            0         NaN          0                 0
# 127  ...            1         NaN          0                 0
# 128  ...            1         NaN          0                 0
#
#      dismissal_kind fielder  current_score  runs_left balls_left wickets
# 124             NaN     NaN              1        222        119      10
# 125             NaN     NaN              2        221        118      10
# 126             NaN     NaN              2        221        117      10
# 127             NaN     NaN              3        220        116      10
# 128             NaN     NaN              4        219        115      10
#
# [5 rows x 24 columns]

# %%
# CRR & RRR
delivery_df['crr']= (delivery_df['current_score']*6)/ (120- delivery_df['balls_left'])
delivery_df['rrr']= (delivery_df['runs_left']*6)/ delivery_df['balls_left']

# %%
delivery_df['batting_team']= delivery_df['batting_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')
delivery_df['bowling_team']= delivery_df['bowling_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')

delivery_df['batting_team']= delivery_df['batting_team'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
delivery_df['bowling_team']= delivery_df['bowling_team'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')

delivery_df['batting_team']= delivery_df['batting_team'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
delivery_df['bowling_team']= delivery_df['bowling_team'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

delivery_df['batting_team']= delivery_df['batting_team'].str.replace('Kings XI Punjab', 'Punjab Kings')
delivery_df['bowling_team']= delivery_df['bowling_team'].str.replace('Kings XI Punjab', 'Punjab Kings')

delivery_df['city']= delivery_df['city'].str.replace('Bangalore', 'Bengaluru')

# %%
delivery_df= delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df= delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df.sample()
# Out:
#         match_id  city               winner  total_runs_x  inning  \
# 125265   1136577  Pune  Chennai Super Kings           205       2
#
#             batting_team         bowling_team  over  ball     batter  ...  \
# 125265  Rajasthan Royals  Chennai Super Kings     4     1  BA Stokes  ...
#
#        is_wicket player_dismissed  dismissal_kind  fielder  current_score  \
# 125265         0                0             NaN      NaN             31
#
#        runs_left  balls_left  wickets   crr        rrr
# 125265       174          95        8  7.44  10.989474
#
# [1 rows x 26 columns]

# %%
def res(row):
    return 1 if row['batting_team']== row['winner'] else 0

# %%
delivery_df['result']= delivery_df.apply(res, axis= 1)

# %%
df= delivery_df[['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left', 'wickets', 'total_runs_x', 'crr', 'rrr', 'result']]

# %%
df= df.sample(df.shape[0])

# %%
df.dropna(inplace= True)

# %%
df= df[df['balls_left'] != 0]

# %%
df['result'].value_counts()
# Out:
# result
# 1    54429
# 0    50914
# Name: count, dtype: int64

# %%
df
# Out:
#                  batting_team                 bowling_team           city  \
# 95841        Rajasthan Royals               Mumbai Indians      Ahmedabad
# 109992         Mumbai Indians        Kolkata Knight Riders         Mumbai
# 89614   Kolkata Knight Riders          Sunrisers Hyderabad      Hyderabad
# 137093    Sunrisers Hyderabad             Rajasthan Royals      Hyderabad
# 70737     Chennai Super Kings             Rajasthan Royals        Chennai
# ...                       ...                          ...            ...
# 202554       Rajasthan Royals         Lucknow Super Giants         Jaipur
# 217753         Delhi Capitals        Kolkata Knight Riders  Visakhapatnam
# 133756  Kolkata Knight Riders          Sunrisers Hyderabad      Hyderabad
# 120426  Kolkata Knight Riders                 Punjab Kings     Chandigarh
# 227913           Punjab Kings  Royal Challengers Bengaluru     Dharamsala
#
#         runs_left  balls_left  wickets  total_runs_x        crr        rrr  \
# 95841          90          56        9           165   7.031250   9.642857
# 109992        160         109        9           175   8.181818   8.807339
# 89614          43          32        8           143   6.818182   8.062500
# 137093        162          96       10           199   9.250000  10.125000
# 70737         107          68        9           186   9.115385   9.441176
# ...           ...         ...      ...           ...        ...        ...
# 202554         51          29        7           155   6.857143  10.551724
# 217753        203          73        6           273   8.936170  16.684932
# 133756         17          16        7           173   9.000000   6.375000
# 120426        129          97        9           168  10.173913   7.979381
# 227913         61          18        1           242  10.647059  20.333333
#
#         result
# 95841        1
# 109992       1
# 89614        1
# 137093       1
# 70737        1
# ...        ...
# 202554       0
# 217753       0
# 133756       1
# 120426       0
# 227913       0
#
# [105343 rows x 10 columns]

# %% [markdown]
# # Model Training

# %%
X= df.iloc[:,:-1]
y= df.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.30, random_state=0)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
trf= ColumnTransformer([
    ('ohe', OneHotEncoder(sparse_output= False, drop='first'), ['batting_team', 'bowling_team', 'city']),
    #('sc', StandardScaler(), ['runs_left', 'balls_left', 'wickets', 'total_runs_x', 'crr', 'rrr'])
], remainder= 'passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe= Pipeline(steps=[
    ('step1', trf),
    ('step2', LogisticRegression(solver= 'liblinear'))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred= pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8011264753346201

# %%
pipe.predict(X_test)[0]
# Out:
# 1

# %%
pipe.predict_proba(X_test)[0]
# Out:
# array([0.24298441, 0.75701559])

# %%
X_test.head()
# Out:
#             batting_team                 bowling_team            city  \
# 218460  Rajasthan Royals  Royal Challengers Bengaluru          Jaipur
# 89844   Rajasthan Royals               Mumbai Indians       Ahmedabad
# 15530     Delhi Capitals  Royal Challengers Bengaluru  Port Elizabeth
# 180669    Mumbai Indians             Rajasthan Royals          Mumbai
# 20643       Punjab Kings          Sunrisers Hyderabad       Kimberley
#
#         runs_left  balls_left  wickets  total_runs_x       crr        rrr
# 218460        123          78        9           184  8.714286   9.461538
# 89844         104          48        3           179  6.250000  13.000000
# 15530          70          45        8           150  6.400000   9.333333
# 180669         81          47        8           194  9.287671  10.340426
# 20643          42          22        4           169  7.775510  11.454545

# %%
df.city.unique()
# Out:
# array(['Ahmedabad', 'Mumbai', 'Hyderabad', 'Chennai', 'Dharamsala',
#        'Bengaluru', 'Pune', 'Abu Dhabi', 'Kolkata', 'Port Elizabeth',
#        'Mohali', 'Delhi', 'Ranchi', 'Dubai', 'Bloemfontein', 'Sharjah',
#        'Jaipur', 'Chandigarh', 'Lucknow', 'Durban', 'Indore', 'Centurion',
#        'Navi Mumbai', 'East London', 'Nagpur', 'Johannesburg', 'Cuttack',
#        'Visakhapatnam', 'Cape Town', 'Guwahati', 'Raipur', 'Kimberley'],
#       dtype=object)

# %%
import pickle
pickle.dump(pipe, open('ipl_pipe.pkl', 'wb'))

# %% [markdown]
# # Toss

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
toss_df= match[['team1', 'team2', 'city', 'match_type', 'toss_winner']]

# %%
def res(row):
    return 1 if row['team1']== row['toss_winner'] else 0

# %%
toss_df['result']= toss_df.apply(res, axis= 1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7756\549844934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toss_df['result']= toss_df.apply(res, axis= 1)

# %%
toss_df= toss_df[['team1', 'team2', 'city', 'match_type', 'result']]

# %%
toss_df.head()
# Out:
#                          team1                        team2        city  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders   Bangalore
# 1              Kings XI Punjab          Chennai Super Kings  Chandigarh
# 2             Delhi Daredevils             Rajasthan Royals       Delhi
# 3               Mumbai Indians  Royal Challengers Bangalore      Mumbai
# 4        Kolkata Knight Riders              Deccan Chargers     Kolkata
#
#   match_type  result
# 0     League       1
# 1     League       0
# 2     League       0
# 3     League       1
# 4     League       0

# %%
toss_df['team1']= toss_df['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
toss_df['team2']= toss_df['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
#toss_df['toss_winner']= toss_df['toss_winner'].str.replace('Delhi Daredevils', 'Delhi Capitals')

toss_df['team1']= toss_df['team1'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
toss_df['team2']= toss_df['team2'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
#toss_df['toss_winner']= toss_df['toss_winner'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')

toss_df['team1']= toss_df['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
toss_df['team2']= toss_df['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
#toss_df['toss_winner']= toss_df['toss_winner'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

toss_df['team1']= toss_df['team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
toss_df['team2']= toss_df['team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
#toss_df['toss_winner']= toss_df['toss_winner'].str.replace('Kings XI Punjab', 'Punjab Kings')

toss_df['city']= toss_df['city'].str.replace('Bangalore', 'Bengaluru')

# %%
toss_df= toss_df[toss_df['team1'].isin(teams)]
toss_df= toss_df[toss_df['team2'].isin(teams)]

# %%
toss_df= toss_df[~toss_df['match_type'].isin(['Elimination Final', '3rd Place Play-Off', 'Semi Final'])]

# %%
toss_df.shape
# Out:
# (970, 5)

# %%
toss_df.head()
# Out:
#                          team1                        team2        city  \
# 0  Royal Challengers Bengaluru        Kolkata Knight Riders   Bengaluru
# 1                 Punjab Kings          Chennai Super Kings  Chandigarh
# 2               Delhi Capitals             Rajasthan Royals       Delhi
# 3               Mumbai Indians  Royal Challengers Bengaluru      Mumbai
# 4        Kolkata Knight Riders          Sunrisers Hyderabad     Kolkata
#
#   match_type  result
# 0     League       1
# 1     League       0
# 2     League       0
# 3     League       1
# 4     League       0

# %%
Xt= toss_df.iloc[:,:-1]
yt= toss_df.iloc[:,-1]

from sklearn.model_selection import train_test_split
Xt_train, Xt_test, yt_train, yt_test= train_test_split(Xt, yt, test_size= 0.20, random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
trft= ColumnTransformer([
    ('ohe', OneHotEncoder(sparse_output= False, drop='first'), ['team1', 'team2', 'city', 'match_type'])
], remainder= 'passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe_t= Pipeline(steps=[
    ('step1', trft),
    ('step2', RandomForestClassifier(random_state=42))
])

# %%
pipe_t.fit(Xt_train, yt_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['team1', 'team2', 'city',
#                                                    'match_type'])])),
#                 ('step2', RandomForestClassifier(random_state=42))])

# %%
yt_pred= pipe_t.predict(Xt_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(yt_test, yt_pred)
# Out:
# 0.5927835051546392

# %%
print(match['toss_winner'].value_counts(normalize=True))
# Out:
# toss_winner
# Mumbai Indians                 0.130594
# Kolkata Knight Riders          0.111416
# Chennai Super Kings            0.111416
# Rajasthan Royals               0.109589
# Royal Challengers Bangalore    0.103196
# Sunrisers Hyderabad            0.080365
# Kings XI Punjab                0.077626
# Delhi Daredevils               0.073059
# Delhi Capitals                 0.045662
# Deccan Chargers                0.039269
# Punjab Kings                   0.021918
# Gujarat Titans                 0.020091
# Pune Warriors                  0.018265
# Lucknow Super Giants           0.017352
# Gujarat Lions                  0.013699
# Kochi Tuskers Kerala           0.007306
# Royal Challengers Bengaluru    0.007306
# Rising Pune Supergiants        0.006393
# Rising Pune Supergiant         0.005479
# Name: proportion, dtype: float64

# %%
pipe_t.predict_proba(Xt_test)[0]
# Out:
# array([0.58145455, 0.41854545])

# %%
import pickle
pickle.dump(pipe_t, open('ipl_toss_pipe.pkl', 'wb'))

# %%
toss_df['match_type'].unique()
# Out:
# array(['League', 'Final', 'Qualifier 1', 'Qualifier 2', 'Eliminator'],
#       dtype=object)
